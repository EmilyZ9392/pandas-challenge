# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
import csv
import os

# %%
# File to Load 
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

# %%
school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Calculate the percentage of students who passed math **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
#Total number of schools
total_schools = len(school_data_complete.school_name.unique())

# %%
total_schools
# Out:
# 15

# %%
#Total number of students
total_students = school_data_complete.student_name.count()

# %%
total_students
# Out:
# 39170

# %%
#Total Budget 
total_budget= sum(school_data_complete.budget.unique())

# %%
total_budget
# Out:
# 24649428

# %%
#Average Math Score 
avg_math = school_data_complete.math_score.mean()

# %%
avg_math
# Out:
# 78.98537145774827

# %%
# Average reading score
avg_read = school_data_complete.reading_score.mean()

# %%
avg_read
# Out:
# 81.87784018381414

# %%
# Percent of student with math score >=70%
percent_pass_math = (school_data_complete[school_data_complete['math_score'] >= 70].math_score.count())/ total_students

# %%
percent_pass_math
# Out:
# 0.749808526933878

# %%
# Percent of students with reading score >= 70%
percent_pass_read = (school_data_complete[school_data_complete['reading_score'] >= 70].reading_score.count()) / total_students

# %%
percent_pass_read
# Out:
# 0.8580546336482001

# %%
# Percent overall passing
percent_pass_overall = school_data_complete[(school_data_complete['math_score'] >= 70) & (school_data_complete['reading_score'] >= 70)].student_name.count() / total_students

# %%
percent_pass_overall
# Out:
# 0.6517232575950983

# %%
#Create datafram for above results

district_summary = pd.DataFrame({
    'Total Schools' : [total_schools],
    'Total Students' : [total_students],
    'Total Budget' : [total_budget],
    'Average Math Score': [avg_math],
    'Average Reading Score' : [avg_read],
    '% of Students Passing Math' :[percent_pass_math*100],
    '% of Students Passing Reading' : [percent_pass_read*100],
    'Overall Passing %' : [percent_pass_overall*100]
})

# %%
district_summary
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           39170      24649428           78.985371
#
#    Average Reading Score  % of Students Passing Math  \
# 0               81.87784                   74.980853
#
#    % of Students Passing Reading  Overall Passing %
# 0                      85.805463          65.172326

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed math **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
# File to Load 
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

# %%
school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
#groups by school
by_school = school_data_complete.set_index('school_name').groupby(['school_name'])

#school types
sch_types = school_data.set_index('school_name')['type']

# total students by school
stu_per_sch = by_school['Student ID'].count()

# school budget
sch_budget = school_data.set_index('school_name')['budget']

#per student budget
stu_budget = school_data.set_index('school_name')['budget']/school_data.set_index('school_name')['size']

#avg scores by school
avg_math = by_school['math_score'].mean()
avg_read = by_school['reading_score'].mean()

# % passing scores
pass_math = school_data_complete[school_data_complete['math_score'] >= 70].groupby('school_name')['Student ID'].count()/stu_per_sch 
pass_read = school_data_complete[school_data_complete['reading_score'] >= 70].groupby('school_name')['Student ID'].count()/stu_per_sch 
overall = school_data_complete[(school_data_complete['reading_score'] >= 70) & (school_data_complete['math_score'] >= 70)].groupby('school_name')['Student ID'].count()/stu_per_sch 

sch_summary = pd.DataFrame({
    "School Type": sch_types,
    "Total Students": stu_per_sch,
    "Per Student Budget": stu_budget,
    "Total School Budget": sch_budget,
    "Average Math Score": avg_math,
    "Average Reading Score": avg_read,
    '% Passing Math': pass_math,
    '% Passing Reading': pass_read,
    "Overall Passing %": overall
})

# %%
sch_summary
# Out:
#                       School Type  Total Students  Per Student Budget  \
# Bailey High School       District            4976               628.0
# Cabrera High School       Charter            1858               582.0
# Figueroa High School     District            2949               639.0
# Ford High School         District            2739               644.0
# Griffin High School       Charter            1468               625.0
# Hernandez High School    District            4635               652.0
# Holden High School        Charter             427               581.0
# Huang High School        District            2917               655.0
# Johnson High School      District            4761               650.0
# Pena High School          Charter             962               609.0
# Rodriguez High School    District            3999               637.0
# Shelton High School       Charter            1761               600.0
# ...

# %% [markdown]
# ## Top Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %%
# Sort by overall passing %, print top 5
top_5 = sch_summary.sort_values('Overall Passing %', ascending= False)
top_5.head()
# Out:
#                     School Type  Total Students  Per Student Budget  \
# Cabrera High School     Charter            1858               582.0
# Thomas High School      Charter            1635               638.0
# Griffin High School     Charter            1468               625.0
# Wilson High School      Charter            2283               578.0
# Pena High School        Charter             962               609.0
#
#                      Total School Budget  Average Math Score  \
# Cabrera High School              1081356           83.061895
# Thomas High School               1043130           83.418349
# Griffin High School               917500           83.351499
# Wilson High School               1319574           83.274201
# Pena High School                  585858           83.839917
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# Cabrera High School              83.975780        0.941335           0.970398
# ...

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %%
top_5.tail()
# Out:
#                       School Type  Total Students  Per Student Budget  \
# Johnson High School      District            4761               650.0
# Hernandez High School    District            4635               652.0
# Huang High School        District            2917               655.0
# Figueroa High School     District            2949               639.0
# Rodriguez High School    District            3999               637.0
#
#                        Total School Budget  Average Math Score  \
# Johnson High School                3094650           77.072464
# Hernandez High School              3022020           77.289752
# Huang High School                  1910635           76.629414
# Figueroa High School               1884411           76.711767
# Rodriguez High School              2547363           76.842711
#
#                        Average Reading Score  % Passing Math  \
# Johnson High School                80.966394        0.660576
# ...

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
#function to create series for average math score by grade

def average_math_by_grade(grade):
    sch_summary = school_data_complete.loc[school_data_complete.grade == grade].groupby (['school_name'])
    school_names = school_data_complete.school_name.sort_values().unique()
    sch_avg_math = list(sch_summary.math_score.mean())
    
    #compile all averages into df
    avg_math_df = pd.DataFrame ({ 'School Names' : school_names,
                                f'{grade} Avg Math Score': sch_avg_math})
    avg_math_df = avg_math_df.reset_index(drop = True)
    return avg_math_df

# %%
#Function to create series for average reading score by grade
def average_reading_by_grade(grade):
    sch_summary = school_data_complete.loc[school_data_complete.grade == grade].groupby (['school_name'])
    school_names = school_data_complete.school_name.sort_values().unique()
    sch_avg_read = list(sch_summary.reading_score.mean())
    
    #compile into df
    avg_read_df = pd.DataFrame ({ 'School Names' : school_names,
                                f'{grade} Avg Reading Score' : sch_avg_read})
    avg_read_df = avg_read_df.reset_index(drop = True)
    return avg_read_df

# %%
#create series and group by school

grade_9 = average_math_by_grade ('9th')
grade_10 = average_math_by_grade ('10th')
grade_11 = average_math_by_grade ('11th')
grade_12 = average_math_by_grade ('12th')
avg_math_score_by_grade = pd.merge(grade_9, grade_10, how = 'inner', suffixes= ('',''))
avg_math_score_by_grade = pd.merge(avg_math_score_by_grade, grade_11, how= 'inner', suffixes = ('',''))
avg_math_score_by_grade = pd.merge(avg_math_score_by_grade, grade_12, how = 'inner', suffixes = ('',''))
avg_math_score_by_grade
# Out:
#              School Names  9th Avg Math Score  10th Avg Math Score  \
# 0      Bailey High School           77.083676            76.996772
# 1     Cabrera High School           83.094697            83.154506
# 2    Figueroa High School           76.403037            76.539974
# 3        Ford High School           77.361345            77.672316
# 4     Griffin High School           82.044010            84.229064
# 5   Hernandez High School           77.438495            77.337408
# 6      Holden High School           83.787402            83.429825
# 7       Huang High School           77.027251            75.908735
# 8     Johnson High School           77.187857            76.691117
# 9        Pena High School           83.625455            83.372000
# 10  Rodriguez High School           76.859966            76.612500
# 11    Shelton High School           83.420755            82.917411
# 12     Thomas High School           83.590022            83.087886
# ...

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
#create series and group by school
grade_9 = average_reading_by_grade('9th')
grade_10 = average_reading_by_grade('10th')
grade_11 = average_reading_by_grade('11th')
grade_12 = average_reading_by_grade('12th')
avg_reading_score_by_grade = pd.merge(grade_9, grade_10, how='inner', suffixes=('',''))
avg_reading_score_by_grade = pd.merge(avg_reading_score_by_grade, grade_11, how = 'inner', suffixes=('',''))
avg_reading_score_by_grade = pd.merge(avg_reading_score_by_grade, grade_12, how='inner', suffixes = ('',''))
avg_reading_score_by_grade
# Out:
#              School Names  9th Avg Reading Score  10th Avg Reading Score  \
# 0      Bailey High School              81.303155               80.907183
# 1     Cabrera High School              83.676136               84.253219
# 2    Figueroa High School              81.198598               81.408912
# 3        Ford High School              80.632653               81.262712
# 4     Griffin High School              83.369193               83.706897
# 5   Hernandez High School              80.866860               80.660147
# 6      Holden High School              83.677165               83.324561
# 7       Huang High School              81.290284               81.512386
# 8     Johnson High School              81.260714               80.773431
# 9        Pena High School              83.807273               83.612000
# 10  Rodriguez High School              80.993127               80.629808
# 11    Shelton High School              84.122642               83.441964
# ...

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
# Create bins
spending_bins = [ 550, 590, 637, 652, 678]
group_names = ['<$585','$585-630','$630-645','$645-680']
school_data_complete['spending_bins'] = pd.cut(school_data_complete['budget']/school_data_complete['size'], spending_bins, labels = group_names)

# %%
#group by spending
by_spending = school_data_complete.groupby ('spending_bins')

# %%
#calcs
avg_math = by_spending['math_score'].mean()
avg_read = by_spending['reading_score'].mean()
pass_math = school_data_complete [school_data_complete['math_score'] >= 70].groupby('spending_bins')['Student ID'].count()/by_spending['Student ID'].count()
pass_read = school_data_complete [school_data_complete['reading_score'] >= 70].groupby('spending_bins')['Student ID'].count()/by_spending['Student ID'].count()
overall = school_data_complete [(school_data_complete['reading_score']>= 70)& (school_data_complete['math_score'] >=70)].groupby('spending_bins')['Student ID'].count()/by_spending['Student ID'].count()

# %%
# create df
scores_by_spend = pd.DataFrame ({
    'Average Math Score' : avg_math,
    'Average Reading Score': avg_read,
    '% Passing Math': (pass_math*100),
    '% Passing Reading': (pass_read*100),
    'Overall Passing %': (overall*100)
})

# %%
scores_by_spend.index.name = 'Spending Ranges Per Student'

# %%
scores_by_spend
# Out:
#                              Average Math Score  Average Reading Score  \
# Spending Ranges Per Student
# <$585                                 83.363065              83.964039
# $585-630                              79.029090              81.836397
# $630-645                              77.694599              81.237155
# $645-680                              76.629414              81.182722
#
#                              % Passing Math  % Passing Reading  \
# Spending Ranges Per Student
# <$585                             93.702889          96.686558
# $585-630                          75.239253          85.994228
# $630-645                          69.268497          82.295592
# $645-680                          65.683922          81.316421
#
#                              Overall Passing %
# Spending Ranges Per Student
# <$585                                90.640704
# $585-630                             65.486860
# $630-645                             57.258209
# ...

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
# Create bins
bins = [ 950, 1050, 2250, 3500]
group_sizes = ['Small (<1000)','Medium (1000-2000)','Large (>2000)']
school_data_complete['size_bins'] = pd.cut(school_data_complete['size'], bins, labels = group_sizes)

# %%
#group by size
by_size = school_data_complete.groupby ('size_bins')

# %%
#calcs
avg_math = by_size['math_score'].mean()
avg_read = by_size['reading_score'].mean()
pass_math = school_data_complete [school_data_complete['math_score'] >= 70].groupby('size_bins')['Student ID'].count()/by_size['Student ID'].count()
pass_read = school_data_complete [school_data_complete['reading_score'] >= 70].groupby('size_bins')['Student ID'].count()/by_size['Student ID'].count()
overall = school_data_complete [(school_data_complete['reading_score']>= 70)& (school_data_complete['math_score'] >=70)].groupby('size_bins')['Student ID'].count()/by_size['Student ID'].count()

# %%
# create df
scores_by_size = pd.DataFrame ({
    'Average Math Score' : avg_math,
    'Average Reading Score': avg_read,
    '% Passing Math': (pass_math*100),
    '% Passing Reading': (pass_read*100),
    'Overall Passing %': (overall*100)
})

# %%
scores_by_size.index.name = 'Size of School'

# %%
scores_by_size
# Out:
#                     Average Math Score  Average Reading Score  % Passing Math  \
# Size of School
# Small (<1000)                83.839917              84.044699       94.594595
# Medium (1000-2000)           83.372682              83.867989       93.616522
# Large (>2000)                78.164034              81.654758       72.336517
#
#                     % Passing Reading  Overall Passing %
# Size of School
# Small (<1000)               95.945946          90.540541
# Medium (1000-2000)          96.773058          90.624267
# Large (>2000)               83.844600          61.397869

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type

# %%
# Create bins
bins = [ 950, 1050, 2250, 3500]
group_sizes = ['Small (<1000)','Medium (1000-2000)','Large (>2000)']
school_data_complete['size_bins'] = pd.cut(school_data_complete['size'], bins, labels = group_sizes)

# %%
#group by type
by_type = school_data_complete.groupby('type')

# %%
#calcs
avg_math = by_type['math_score'].mean()
avg_read = by_type['reading_score'].mean()
pass_math = school_data_complete [school_data_complete['math_score'] >= 70].groupby('type')['Student ID'].count()/by_type['Student ID'].count()
pass_read = school_data_complete [school_data_complete['reading_score'] >= 70].groupby('type')['Student ID'].count()/by_type['Student ID'].count()
overall = school_data_complete [(school_data_complete['reading_score']>= 70)& (school_data_complete['math_score'] >=70)].groupby('type')['Student ID'].count()/by_type['Student ID'].count()

# %%
# create df
scores_by_type = pd.DataFrame ({
    'Average Math Score' : avg_math,
    'Average Reading Score': avg_read,
    '% Passing Math': (pass_math*100),
    '% Passing Reading': (pass_read*100),
    'Overall Passing %': (overall*100)
})

# %%
scores_by_type.index.name = 'Type of School'

# %%
scores_by_type
# Out:
#                 Average Math Score  Average Reading Score  % Passing Math  \
# Type of School
# Charter                  83.406183              83.902821       93.701821
# District                 76.987026              80.962485       66.518387
#
#                 % Passing Reading  Overall Passing %
# Type of School
# Charter                 96.645891          90.560932
# District                80.905249          53.695878
